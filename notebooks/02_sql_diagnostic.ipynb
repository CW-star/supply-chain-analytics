# %%
# ============================================================
# PHASE 2 — SQL DIAGNOSTIC: COMPLETE FINDINGS DOCUMENT
# ============================================================

findings = """
╔══════════════════════════════════════════════════════════════════════╗
║         PHASE 2 COMPLETE — SQL DIAGNOSTIC FINDINGS                  ║
║         DataCo Global Supply Chain | 180,519 Orders | 2015–2018     ║
╠══════════════════════════════════════════════════════════════════════╣
║                                                                      ║
║  FINDING 1: First Class Shipping is Operationally Broken             ║
║  ─────────────────────────────────────────────────────               ║
║  95.3% of First Class orders arrive late across all markets.         ║
║  This is not a regional issue — First Class fails at 94.7%           ║
║  in LATAM, 95.1% in Pacific Asia, 95.8% in Europe, and              ║
║  97.0% in Africa. Customers paying premium prices receive            ║
║  the worst service in every single market.                           ║
║                                                                      ║
║  Recommendation: Suspend First Class until carrier SLAs              ║
║  are renegotiated. Redirect volume to Standard Class.                ║
║                                                                      ║
║  FINDING 2: Late Delivery is Systemic, Not Regional                  ║
║  ─────────────────────────────────────────────────────               ║
║  Every region has a late delivery rate between 55–58%.               ║
║  Central Africa leads at 58.0%, but Western Europe —                 ║
║  the highest volume region with 27,109 orders — sits                 ║
║  at 55.8%, meaning 15,140 deliveries failed in one region.           ║
║  The consistency across regions points to a central                  ║
║  logistics or forecasting failure, not local execution.              ║
║                                                                      ║
║  Recommendation: Audit central warehouse processing times            ║
║  and carrier handoff procedures before blaming regional ops.         ║
║                                                                      ║
║  FINDING 3: Computers Are Being Sold at a Structural Loss            ║
║  ─────────────────────────────────────────────────────               ║
║  9 of the 10 worst individual orders are Computers,                  ║
║  with losses ranging from -$2,255 to -$3,443 per order.             ║
║  Critically, discounts on these orders are minimal (0–12%),          ║
║  meaning the loss is baked into the pricing or cost structure,       ║
║  not driven by promotions. Western Europe and Pacific Asia           ║
║  are the most affected markets.                                      ║
║                                                                      ║
║  Recommendation: Immediately review Computer product pricing         ║
║  and landed cost calculations for Europe and Pacific Asia.           ║
║                                                                      ║
║  FINDING 4: A Demand Shock Collapsed Order Volume in Oct 2017        ║
║  ─────────────────────────────────────────────────────               ║
║  From Jan 2015 to Sep 2017, monthly orders held steady               ║
║  at 4,700–5,400. In October 2017, volume collapsed from              ║
║  5,189 to 2,255 — a 56.5% drop in a single month.                   ║
║  The business never recovered: Nov 2017 (2,055 orders),              ║
║  Dec 2017 (2,124), Jan 2018 (2,123). Total profit fell               ║
║  from $122K/month to $34K/month by January 2018.                     ║
║                                                                      ║
║  Recommendation: Investigate October 2017 for market exit,           ║
║  system migration, or major customer churn event.                    ║
║                                                                      ║
║  FINDING 5: First Class Generates Profit Despite Poor Service        ║
║  ─────────────────────────────────────────────────────               ║
║  Despite a 95%+ late delivery rate, First Class shipping             ║
║  remains profitable: $193K in Europe, $184K in LATAM,               ║
║  $141K in Pacific Asia. This creates a dangerous dynamic —           ║
║  the business has no short-term financial incentive to fix           ║
║  a service failure that is eroding customer trust long-term.         ║
║                                                                      ║
║  Recommendation: Model customer lifetime value impact of             ║
║  late deliveries to make the long-term cost visible to leadership.   ║
║                                                                      ║
╚══════════════════════════════════════════════════════════════════════╝
"""
print(findings)
# Out:
# ╔══════════════════════════════════════════════════════════════════════╗
# ║         PHASE 2 COMPLETE — SQL DIAGNOSTIC FINDINGS                  ║
# ║         DataCo Global Supply Chain | 180,519 Orders | 2015–2018     ║
# ╠══════════════════════════════════════════════════════════════════════╣
# ║                                                                      ║
# ║  FINDING 1: First Class Shipping is Operationally Broken             ║
# ║  ─────────────────────────────────────────────────────               ║
# ║  95.3% of First Class orders arrive late across all markets.         ║
# ║  This is not a regional issue — First Class fails at 94.7%           ║
# ║  in LATAM, 95.1% in Pacific Asia, 95.8% in Europe, and              ║
# ║  97.0% in Africa. Customers paying premium prices receive            ║
# ║  the worst service in every single market.                           ║
# ║                                                                      ║
# ...
